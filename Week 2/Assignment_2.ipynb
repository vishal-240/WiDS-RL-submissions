# %% [markdown]
# ### Assignment : Week 1
# ## Modeling simple RL problems by making their MDPs in Python
#
# We will create the MDPs for some of the example problems from Grokking textbook. For the simple environments, we can just hardcode the MDPs into a dictionary by exhaustively encoding the whole state space and the transition function. We will also go through a more complicated example where the state space is too large to be manually coded and we need to implement the transition function based on some state parameters.
#
# Later on, you will not need to implement the MDPs of common RL problems yourself, most of the work is already done by the OpenAI Gym library, which includes models for most of the famous RL envis.
#
# You can start this assignment during/after reading Grokking Ch-2.

# %% [markdown]
# ## Environment 0 - Bandit Walk
#
# Let us consider the BW environment on Page 39.
#
# State Space has 3 elements, states 0, 1 and 2.
# States 0 and 2 are terminal states and state 1 is the starting state.
#
# Action space has 2 elements, left and right.
#
# The environment is deterministic - transition probability of any action is 1.
#
# Only 1 (State, Action, State') tuple has positive reward, (1, Right, 2) gives the agent +1 reward.

# %% [markdown]
# We'll model this MDP as a dictionary. This code is an example for the upcoming exercises.

# %%
bw_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)]
    },

    1 : {
        "Right" : [(1, 2, 1, True)],
        "Left" : [(1, 0, 0, True)]
    },

    2 : {
        "Right" : [(1, 2, 0, True)],
        "Left" : [(1, 2, 0, True)]
    }
    
}

# %% [markdown]
# Note that by convention, all actions from terminal states still lead to the same state with reward 0.

# %% [markdown]
# ## Environment 1 - Slippery Walk
#
# Let us now look at the BSW environment on Page 40. We'll model a slightly modified version of BSW with 7 states instead (i.e the SWF envi on Page 67). It will be useful in the coming weeks.
#
# Here, states 0 and 6 are terminal states and state 3 is the starting state.
#
# Action space has again 2 elements, left and right.
#
# The environment is now stochastic, transition probability of any action is as follows -
# If agent chooses `Right` at a non-terminal state,
# - $50\%$ times it will go to `Right` state
# - $33\frac{1}{3} \%$ times it will stay in same state
# - $16\frac{2}{3}\%$ times it will go to `Left`state
#
# This time, 2 different (State, Action, State') tuples have positive rewards, you need to find them.

# %% [markdown]
# We'll again model this MDP as a dictionary. Part of the code is written for you.

# %%
swf_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)],
    },

    1 : {
        "Right" : [
            (1/2, 2, 0, False),
            (1/3, 1, 0, False),
            (1/6, 0, 0, True),
        ],
        "Left" : [
            # to be added
            (1/2, 0, 0, True),
            (1/3, 1, 0, False),
            (1/6, 2, 0, False),
        ]
    }, 

    # to be added 
    2 : {
        "Right" : [
            (1/2, 3, 0, False),
            (1/3, 2, 0, False),
            (1/6, 1, 0, False),
        ],
        "Left" : [
            (1/2, 1, 0, False),
            (1/3, 2, 0, False),
            (1/6, 3, 0, False),
        ]
    },
    3 : {
        "Right" : [
            (1/2, 4, 0, False),
            (1/3, 3, 0, False),
            (1/6, 2, 0, False),
        ],
        "Left" : [
            (1/2, 2, 0, False),
            (1/3, 3, 0, False),
            (1/6, 4, 0, False),
        ]
    },
    4 : {
        "Right" : [
            (1/2, 5, 0, False),
            (1/3, 4, 0, False),
            (1/6, 3, 0, False),
        ],
        "Left" : [
            (1/2, 3, 0, False),
            (1/3, 4, 0, False),
            (1/6, 5, 0, False),
        ]
    },
    5 : {
        "Right" : [
            (1/2, 6, 1, True),
            (1/3, 5, 0, False),
            (1/6, 4, 0, False),
        ],
        "Left" : [
            (1/2, 4, 0, False),
            (1/3, 5, 0, False),
            (1/6, 6, 1, True),
        ]
    },
    6 : {
        "Right" : [(1, 6, 0, True)],
        "Left" : [(1, 6, 0, True)],
    },
    
}

# %% [markdown]
# Feel free to automate filling this MDP, but ensure that it is correctly filled as it'll be back in next week's assignment.

# %% [markdown]
# ## Environment 2 - Frozen Lake Environment
#
# This environment is described on Page 46.
#
# The FL environment has a large state space, so it's better to generate most of the MDP via Python instead of typing stuff manually.
#
# Note that all 5 states - 5, 7, 11, 12, 15 are terminal states, so keep that in mind while constructing the MDP.
#
# There are 4 actions now - Up, Down, Left, Right.
#
# The environment is stochastic, and states at the border of lake will require separate treatment.

# %% [markdown]
# Yet again we will model this MDP as a (large) dictionary.

# %%
fl_mdp = {
    # to be added
}
def new_state( state, action):
    if state>=0 and state<4:
        row,col = (0, state)
    elif state>3 and state<8:
        row,col = (1,state-4)
    elif state>7 and state<12:
        row,col = (2,state-8)
    else:
        row,col = (3,state-12)

    if action == 0: # 0 -> UP
        row = max(0, row-1)
    elif action == 1: # 1 -> DOWN
        row = min(3, row+1)
    elif action == 2: # 2 -> LEFT
        col = max(0, col-1)
    elif action == 3: # 3 -> RIGHT
        col = min(3, col+1)

    return row*4 + col

def normal_states(state, action):
    if state>=0 and state<4:
        row,col = (0, state)
    elif state>3 and state<8:
        row,col = (1,state-4)
    elif state>7 and state<12:
        row,col = (2,state-8)
    else:
        row,col = (3,state-12)

    if action == 0: # 0 -> UP
        col1 = max(0, col-1)
        row1 = row
        col2 = min(3, col+1)
        row2 = row
    elif action == 1: # 1 -> DOWN
        col2 = max(0, col-1)
        row2 = row
        col1 = min(3, col+1)
        row1 = row
    elif action == 2: # 2 -> LEFT
        row2 = max(0, row-1)
        col2 = col
        row1 = min(3, row+1)
        col1 = col
    elif action == 3: # 3 -> RIGHT
        row1 = max(0, row-1)
        col1 = col
        row2 = min(3, row+1)
        col2 = col

    return row1*4 + col1 , row2*4 + col2

# %%
for state in range(0, 16):

    # add transitions to other states
    transitions = {}

    for action in [0, 1, 2, 3]:
        if state == 5 or state == 7 or state == 11 or state == 12 or state == 15:
            transitions[action] = [
                (1, state, 0, True)
            ]
        elif state == 14:
            if action == 2:
                transitions[action] = [
                    (1/3, new_state(14, 2), 0, False),
                    (1/3, 14, 0, False),
                    (1/3, 10, 0, False)
                ]
            elif action == 0 or action == 1:
                transitions[action] = [
                    (1/3, 15, 1, True),
                    (1/3, new_state(14, action), 0, False),
                    (1/3, 13, 0, False)
                ]
            else:
                transitions[action] = [
                    (1/3, 15, 1, True),
                    (1/3, 10, 0, False),
                    (1/3, 14, 0, False)
                ]
        else:
            n1,n2 = normal_states(state, action)
            n = new_state(state, action)
            b,b1,b2 = False,False,False
            if n == 5 or n == 7 or n == 11 or n == 12:
                b = True
            if n1 == 5 or n1 == 7 or n1 == 11 or n1 == 12:
                b1 = True
            if n2 == 5 or n2 == 7 or n2 == 11 or n2 == 12:
                b2 = True
            transitions[action] = [
                (1/3, n, 0, b),
                (1/3, n1, 0, b1),
                (1/3, n2, 0, b2)
            ]

    fl_mdp[state] = transitions

# %%
fl_mdp
# Out:
# {0: {0: [(0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 1, 0, False)],
#   1: [(0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 0, 0, False)],
#   2: [(0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 0, 0, False)],
#   3: [(0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 4, 0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 2, 0, False)],
#   1: [(0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 0, 0, False)],
#   2: [(0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 1, 0, False)],
#   3: [(0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 5, 0, True)]},
#  2: {0: [(0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 3, 0, False)],
#   1: [(0.3333333333333333, 6, 0, False),
#    (0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 1, 0, False)],
#   2: [(0.3333333333333333, 1, 0, False),
#    (0.3333333333333333, 6, 0, False),
#    (0.3333333333333333, 2, 0, False)],
#   3: [(0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 6, 0, False)]},
#  3: {0: [(0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 3, 0, False)],
#   1: [(0.3333333333333333, 7, 0, True),
#    (0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 2, 0, False)],
#   2: [(0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 7, 0, True),
#    (0.3333333333333333, 3, 0, False)],
#   3: [(0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 3, 0, False),
#    (0.3333333333333333, 7, 0, True)]},
#  4: {0: [(0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 5, 0, True)],
#   1: [(0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 4, 0, False)],
#   2: [(0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 0, 0, False)],
#   3: [(0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 0, 0, False),
#    (0.3333333333333333, 8, 0, False)]},
#  5: {0: [(1, 5, 0, True)],
#   1: [(1, 5, 0, True)],
#   2: [(1, 5, 0, True)],
#   3: [(1, 5, 0, True)]},
#  6: {0: [(0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 7, 0, True)],
#   1: [(0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 7, 0, True),
#    (0.3333333333333333, 5, 0, True)],
#   2: [(0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 2, 0, False)],
#   3: [(0.3333333333333333, 7, 0, True),
#    (0.3333333333333333, 2, 0, False),
#    (0.3333333333333333, 10, 0, False)]},
#  7: {0: [(1, 7, 0, True)],
#   1: [(1, 7, 0, True)],
#   2: [(1, 7, 0, True)],
#   3: [(1, 7, 0, True)]},
#  8: {0: [(0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 9, 0, False)],
#   1: [(0.3333333333333333, 12, 0, True),
#    (0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 8, 0, False)],
#   2: [(0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 12, 0, True),
#    (0.3333333333333333, 4, 0, False)],
#   3: [(0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 4, 0, False),
#    (0.3333333333333333, 12, 0, True)]},
#  9: {0: [(0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 10, 0, False)],
#   1: [(0.3333333333333333, 13, 0, False),
#    (0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 8, 0, False)],
#   2: [(0.3333333333333333, 8, 0, False),
#    (0.3333333333333333, 13, 0, False),
#    (0.3333333333333333, 5, 0, True)],
#   3: [(0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 5, 0, True),
#    (0.3333333333333333, 13, 0, False)]},
#  10: {0: [(0.3333333333333333, 6, 0, False),
#    (0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 11, 0, True)],
#   1: [(0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 11, 0, True),
#    (0.3333333333333333, 9, 0, False)],
#   2: [(0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 6, 0, False)],
#   3: [(0.3333333333333333, 11, 0, True),
#    (0.3333333333333333, 6, 0, False),
#    (0.3333333333333333, 14, 0, False)]},
#  11: {0: [(1, 11, 0, True)],
#   1: [(1, 11, 0, True)],
#   2: [(1, 11, 0, True)],
#   3: [(1, 11, 0, True)]},
#  12: {0: [(1, 12, 0, True)],
#   1: [(1, 12, 0, True)],
#   2: [(1, 12, 0, True)],
#   3: [(1, 12, 0, True)]},
#  13: {0: [(0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 12, 0, True),
#    (0.3333333333333333, 14, 0, False)],
#   1: [(0.3333333333333333, 13, 0, False),
#    (0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 12, 0, True)],
#   2: [(0.3333333333333333, 12, 0, True),
#    (0.3333333333333333, 13, 0, False),
#    (0.3333333333333333, 9, 0, False)],
#   3: [(0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 9, 0, False),
#    (0.3333333333333333, 13, 0, False)]},
#  14: {0: [(0.3333333333333333, 15, 1, True),
#    (0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 13, 0, False)],
#   1: [(0.3333333333333333, 15, 1, True),
#    (0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 13, 0, False)],
#   2: [(0.3333333333333333, 13, 0, False),
#    (0.3333333333333333, 14, 0, False),
#    (0.3333333333333333, 10, 0, False)],
#   3: [(0.3333333333333333, 15, 1, True),
#    (0.3333333333333333, 10, 0, False),
#    (0.3333333333333333, 14, 0, False)]},
#  15: {0: [(1, 15, 0, True)],
#   1: [(1, 15, 0, True)],
#   2: [(1, 15, 0, True)],
#   3: [(1, 15, 0, True)]}}

# %% [markdown]
# You might need to do some stuff manually, but make sure to automate most of it.

# %% [markdown]
# You can check your implementation of the FL environment by comparing it with the one in OpenAI Gym.
#
# You don't need to worry about Gym right now, we'll set it up in the coming weeks. But here is the code to import an MDP.

# %%
import gym
P = gym.make('FrozenLake-v1').env.P

# %% [markdown]
# Since the imported MDP is also just a dictionary, we can just print it.

# %%
# using the pretty print module

import pprint
pprint.pprint(P)
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      2: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      2: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      3: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  2: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False)],
#      1: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)]},
#  3: {0: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      1: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)]},
#  4: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)],
#      1: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      2: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)]},
#  5: {0: [(1.0, 5, 0, True)],
#      1: [(1.0, 5, 0, True)],
#      2: [(1.0, 5, 0, True)],
#      3: [(1.0, 5, 0, True)]},
#  6: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False)],
#      1: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      2: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)]},
#  7: {0: [(1.0, 7, 0, True)],
#      1: [(1.0, 7, 0, True)],
#      2: [(1.0, 7, 0, True)],
#      3: [(1.0, 7, 0, True)]},
#  8: {0: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False)],
#      2: [(0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      3: [(0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)]},
#  9: {0: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False)],
#      2: [(0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      3: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False)]},
#  10: {0: [(0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False)],
#       3: [(0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)]},
#  11: {0: [(1.0, 11, 0, True)],
#       1: [(1.0, 11, 0, True)],
#       2: [(1.0, 11, 0, True)],
#       3: [(1.0, 11, 0, True)]},
#  12: {0: [(1.0, 12, 0, True)],
#       1: [(1.0, 12, 0, True)],
#       2: [(1.0, 12, 0, True)],
#       3: [(1.0, 12, 0, True)]},
#  13: {0: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False)],
#       1: [(0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       2: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)],
#       3: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True)]},
#  14: {0: [(0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False)],
#       3: [(0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False)]},
#  15: {0: [(1.0, 15, 0, True)],
#       1: [(1.0, 15, 0, True)],
#       2: [(1.0, 15, 0, True)],
#       3: [(1.0, 15, 0, True)]}}
